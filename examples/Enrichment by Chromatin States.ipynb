# %%
import xmlrpclib
import time
import os.path
import errno

from collections import defaultdict
from pprint import pprint
from multiprocessing import Pool
from socket import error as socket_error

import cPickle

# %%
# Internal configurations
# Do not change this value unless you really know what you are doing.
MAX_REQUEST_SIMULTANEOUS = 16
CACHE_PATH = ".cache"
STATES_CACHE_FILE = "css_queries_cache.deepblue"
DEEPBLUE_URL = "http://deepblue.mpi-inf.mpg.de/xmlrpc"
#DEEPBLUE_URL = "http://localhost:31415"
USER_KEY = 'anonymous_key'

# User parameters (TODO: move to args)
GENOME = 'GRCh38'

# %%
def request_data(request_id):
    (status, info) = SERVER.info(request_id, USER_KEY)
    request_status = info[0]["state"]

    while request_status != "done" and request_status != "failed":
        print info
        time.sleep(10)
        (status, info) = SERVER.info(request_id, USER_KEY)
        request_status = info[0]["state"]

    print "Downloading data"
    (status, data) = SERVER.get_request_data(request_id, USER_KEY)
    if status != "okay":
        print data
        return None

    
    return data

# %%
def split_file(data):
    server_worker = xmlrpclib.Server(DEEPBLUE_URL, allow_none=True)

    [css_file, states] = data
    result = []

    while True:
        try:
            _, css_file_query_id = server_worker.select_experiments(
                css_file, None, None, None, USER_KEY)
            _, css_file_query_cache_id = server_worker.query_cache(
                css_file_query_id, True, USER_KEY)
            for state in states:
                _, css_file_filter_query_id = server_worker.filter_regions(
                    css_file_query_cache_id, "NAME", "==", state, "string", USER_KEY)
                result.append((state, css_file_filter_query_id))

            print css_file
            return css_file, result
        except socket_error as serr:
            print serr

# %%
def get_chromatin_stes(genome, user_key):

    status, csss_query_id = SERVER.select_regions(
        None, genome, "Chromatin State Segmentation",
        None, None, None, None, None, None, user_key)
    print status, csss_query_id

    status, csss_names_request_id = SERVER.distinct_column_values(
        csss_query_id, "NAME", user_key)
    print csss_names_request_id
    distinct_values = request_data(csss_names_request_id)
    print distinct_values['distinct']

    return distinct_values['distinct']

# %%
def build_chromatin_state_files(server, genome, user_key):
    cache_file = os.path.join(CACHE_PATH, STATES_CACHE_FILE)

    if os.path.exists(cache_file):
        _file = open(cache_file, "r")
        queries = cPickle.load(_file)
        return queries
    else:
        _, css_files_list = server.list_experiments(
            genome, "peaks", "Chromatin State Segmentation", None, None, None, None, user_key)
        _, css_files_names = server.extract_names(css_files_list)
        states = get_chromatin_stes(genome, user_key)

        css_files = []
        for css_file in css_files_names:
            css_files.append([css_file, states])

        pool = Pool(MAX_REQUEST_SIMULTANEOUS)
        queries = pool.map(split_file, css_files)
        pprint(queries)
        datasets = defaultdict(list)

        for query in queries:
            for state in query[1]:
                datasets[query[0]].append([state[1], state[0]])

        datasets = dict(datasets)

        print datasets

        pool.close()
        pool.join()

        try:
            os.makedirs(CACHE_PATH)
        except OSError as exc:  # Python >2.5
            if exc.errno == errno.EEXIST and os.path.isdir(CACHE_PATH):
                pass
            else:
                raise

        _file = open(cache_file, "w+")
        # print queries
        cPickle.dump(datasets, _file)
        return datasets

# %%
SERVER = xmlrpclib.Server(DEEPBLUE_URL, allow_none=True)
print SERVER.echo(USER_KEY)

# Query data
# Select the hypo methylated regions where the AVG methyl level is lower
# than 0.0025
_, QUERY_ID = SERVER.select_experiments(
    "S00VEQA1.hypo_meth.bs_call.GRCh38.20150707.bed", None, None, None, USER_KEY)
_, QUERY_ID = SERVER.filter_regions(
    QUERY_ID, "AVG_METHYL_LEVEL", "<", "0.0025", "number", USER_KEY)
print QUERY_ID

# Universe will be tiling regions of 1000bp
_, UNIVERSE_QUERY_ID = SERVER.tiling_regions(1000, "grch38", None, USER_KEY)

# Datasets will be the chromatin segmentation files divided by segments
DATASETS = build_chromatin_state_files(SERVER, GENOME, USER_KEY)
print "total of " + str(len(DATASETS)) + " datasets"
# Out:
# ['okay', 'DeepBlue (1.17.7) says hi to anonymous']
# q978455
# total of 173 datasets

# %%
__, ENRICH_REQUEST = SERVER.enrich_regions_overlap(QUERY_ID, UNIVERSE_QUERY_ID, DATASETS, "grch38", USER_KEY)
print "Processing enrich_region_overlap: ", ENRICH_REQUEST

ENRICHMENT_RESULT = request_data(ENRICH_REQUEST)
# Out:
# Processing enrich_region_overlap:  r822256
# Downloading data

# %%
state_rank = [(k["description"], k["mean_rank"]) for k in ENRICHMENT_RESULT["enrichment"]["results"]]
pprint(state_rank)
# Out:
# [('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 30.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 33.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 37.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 40.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 40.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 42.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 53.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 54.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 55.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 55.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 55.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 55.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 56.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 56.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 56.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 56.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 56.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 57.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 58.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 58.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 58.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 59.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 59.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 60.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 60.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 61.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 62.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 62.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 62.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 63.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 63.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 63.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 63.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 64.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 64.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 65.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 65.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 65.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 65.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 66.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 66.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 66.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 67.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 67.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 67.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 67.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 67.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 67.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 68.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 68.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 68.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 68.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 69.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 69.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 69.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 69.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 69.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 70.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 70.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 70.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 70.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 70.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 70.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 71.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 71.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 71.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 71.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 71.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 72.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 72.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 73.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 73.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 73.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 74.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 74.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 75.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 75.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 75.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 76.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 76.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 76.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 76.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 76.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 76.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 76.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 77.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 77.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 77.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 77.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 77.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 78.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 78.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 78.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 79.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 79.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 79.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 79.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 79.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 80.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 80.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 81.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 82.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 83.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 83.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 83.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 83.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 83.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 84.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 84.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 84.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 84.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 85.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 85.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 85.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 85.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 86.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 86.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 86.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 87.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 87.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 87.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 87.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 87.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 87.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 88.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 89.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 90.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 91.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 92.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 92.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 93.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 94.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 94.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 96.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 96.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 97.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 97.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 98.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 98.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 98.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 98.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 99.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 99.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 100.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 101.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 101.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 103.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 103.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 103.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 104.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 104.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 104.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 104.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 105.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 106.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 107.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 107.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 107.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 108.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 108.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 108.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 108.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 110.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 110.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 111.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 112.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 114.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 115.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 116.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 116.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 117.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 118.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 118.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 119.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 119.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 120.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 120.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 123.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 123.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 124.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 124.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 124.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 125.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 125.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 125.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 125.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 125.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 127.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 128.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 128.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 128.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 129.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 131.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 134.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 134.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 135.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 136.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 138.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 139.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 140.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 141.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 141.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 143.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 143.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 143.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 144.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 145.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 145.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 147.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 148.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 148.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 149.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 152.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 152.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 153.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 153.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 154.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 155.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 156.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 158.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 160.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 160.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 161.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 161.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 162.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 163.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 164.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 164.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 166.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 167.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 168.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 169.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 169.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 171.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 172.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 173.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 173.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 174.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 175.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 176.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 177.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 177.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 178.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 179.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 179.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 180.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 181.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 182.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 183.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 183.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 184.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 185.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 186.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 186.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 186.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 190.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 191.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 192.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 192.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 193.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 194.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 195.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 195.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 196.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 197.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 198.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 198.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 198.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 198.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 201.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 202.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 204.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 205.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 205.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 206.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 206.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 206.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 206.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 207.3333),
#  ('8_Enhancer_High', 208.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 208.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 208.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 209.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 209.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 210.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 213.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 214.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 214.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 215.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 216.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 216.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 217.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 217.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 220.0),
#  ('9_Active_Enhancer_High', 220.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 222.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 222.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 222.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 224.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 224.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 224.6667),
#  ('8_Enhancer_High', 226.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 227.6667),
#  ('8_Enhancer_High', 229.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 229.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 231.3333),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 232.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 233.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 233.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 235.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 238.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 238.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 241.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 244.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 245.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 247.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 247.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 248.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 250.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 250.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 252.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 252.6667),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 253.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 253.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 254.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 255.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 256.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 257.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 259.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 260.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 261.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 263.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 264.3333),
#  ('9_Active_Enhancer_High', 266.0),
#  ('8_Enhancer_High', 267.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 268.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 270.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 270.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 271.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 272.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 272.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 273.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 273.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 274.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 276.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 277.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 277.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 277.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 278.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 279.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 279.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 280.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 280.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 281.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 287.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 288.0),
#  ('12_Active_TSS_High_Signal_H3K4me3_H3K27Ac', 292.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 292.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 292.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 293.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 294.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 295.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 295.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 297.3333),
#  ('8_Enhancer_High', 300.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 303.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 303.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 305.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 306.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 308.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 308.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 308.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 309.0),
#  ('8_Enhancer_High', 310.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 311.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 312.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 312.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 313.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 313.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 313.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 314.6667),
#  ('8_Enhancer_High', 315.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 316.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 316.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 316.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 316.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 320.3333),
#  ('8_Enhancer_High', 320.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 321.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 321.3333),
#  ('8_Enhancer_High', 321.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 322.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 323.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 326.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 326.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 329.3333),
#  ('8_Enhancer_High', 331.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 331.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 333.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 333.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 333.3333),
#  ('9_Active_Enhancer_High', 333.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 334.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 336.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 336.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 339.6667),
#  ('9_Active_Enhancer_High', 340.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 340.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 341.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 341.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 342.0),
#  ('8_Enhancer_High', 342.6667),
#  ('9_Active_Enhancer_High', 344.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 344.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 347.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 349.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 349.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 350.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 352.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 353.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 355.6667),
#  ('8_Enhancer_High', 356.3333),
#  ('8_Enhancer_High', 357.0),
#  ('8_Enhancer_High', 357.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 357.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 358.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 366.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 366.3333),
#  ('8_Enhancer_High', 367.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 367.3333),
#  ('8_Enhancer_High', 367.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 367.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 369.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 370.3333),
#  ('8_Enhancer_High', 372.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 372.6667),
#  ('9_Active_Enhancer_High', 373.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 374.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 376.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 377.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 377.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 379.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 379.3333),
#  ('8_Enhancer_High', 382.3333),
#  ('8_Enhancer_High', 383.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 384.3333),
#  ('8_Enhancer_High', 385.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 385.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 386.3333),
#  ('8_Enhancer_High', 389.0),
#  ('9_Active_Enhancer_High', 390.0),
#  ('8_Enhancer_High', 390.6667),
#  ('8_Enhancer_High', 390.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 391.0),
#  ('8_Enhancer_High', 392.0),
#  ('9_Active_Enhancer_High', 398.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 398.0),
#  ('8_Enhancer_High', 399.0),
#  ('8_Enhancer_High', 400.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 400.3333),
#  ('8_Enhancer_High', 402.3333),
#  ('8_Enhancer_High', 403.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 404.0),
#  ('8_Enhancer_High', 406.6667),
#  ('8_Enhancer_High', 408.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 410.0),
#  ('8_Enhancer_High', 410.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 410.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 412.3333),
#  ('9_Active_Enhancer_High', 413.3333),
#  ('8_Enhancer_High', 413.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 414.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 415.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 416.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 417.0),
#  ('8_Enhancer_High', 417.0),
#  ('8_Enhancer_High', 417.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 421.0),
#  ('9_Active_Enhancer_High', 421.6667),
#  ('8_Enhancer_High', 422.0),
#  ('9_Active_Enhancer_High', 423.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 423.6667),
#  ('9_Active_Enhancer_High', 423.6667),
#  ('8_Enhancer_High', 424.3333),
#  ('9_Active_Enhancer_High', 425.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 426.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 427.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 428.0),
#  ('8_Enhancer_High', 428.0),
#  ('8_Enhancer_High', 428.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 428.6667),
#  ('8_Enhancer_High', 429.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 430.0),
#  ('1_Repressed_Polycomb_High', 431.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 431.6667),
#  ('8_Enhancer_High', 432.0),
#  ('8_Enhancer_High', 432.6667),
#  ('8_Enhancer_High', 432.6667),
#  ('8_Enhancer_High', 433.3333),
#  ('8_Enhancer_High', 433.3333),
#  ('9_Active_Enhancer_High', 435.6667),
#  ('9_Active_Enhancer_High', 437.3333),
#  ('1_Repressed_Polycomb_High', 439.3333),
#  ('8_Enhancer_High', 439.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 440.0),
#  ('9_Active_Enhancer_High', 441.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 441.6667),
#  ('8_Enhancer_High', 442.6667),
#  ('1_Repressed_Polycomb_High', 443.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 444.3333),
#  ('1_Repressed_Polycomb_High', 446.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 446.6667),
#  ('8_Enhancer_High', 446.6667),
#  ('9_Active_Enhancer_High', 447.0),
#  ('1_Repressed_Polycomb_High', 448.0),
#  ('1_Repressed_Polycomb_High', 448.3333),
#  ('1_Repressed_Polycomb_High', 448.6667),
#  ('9_Active_Enhancer_High', 449.3333),
#  ('9_Active_Enhancer_High', 449.3333),
#  ('8_Enhancer_High', 449.6667),
#  ('9_Active_Enhancer_High', 450.0),
#  ('8_Enhancer_High', 450.6667),
#  ('1_Repressed_Polycomb_High', 451.0),
#  ('1_Repressed_Polycomb_High', 452.0),
#  ('8_Enhancer_High', 453.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 453.0),
#  ('1_Repressed_Polycomb_High', 453.0),
#  ('9_Active_Enhancer_High', 453.0),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 454.6667),
#  ('9_Active_Enhancer_High', 454.6667),
#  ('9_Active_Enhancer_High', 454.6667),
#  ('8_Enhancer_High', 455.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 455.6667),
#  ('8_Enhancer_High', 456.6667),
#  ('8_Enhancer_High', 457.3333),
#  ('9_Active_Enhancer_High', 457.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 459.3333),
#  ('1_Repressed_Polycomb_High', 459.3333),
#  ('8_Enhancer_High', 460.3333),
#  ('1_Repressed_Polycomb_High', 460.6667),
#  ('1_Repressed_Polycomb_High', 461.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 461.3333),
#  ('8_Enhancer_High', 462.0),
#  ('1_Repressed_Polycomb_High', 463.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 463.6667),
#  ('8_Enhancer_High', 464.6667),
#  ('8_Enhancer_High', 467.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 467.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 468.0),
#  ('8_Enhancer_High', 468.6667),
#  ('1_Repressed_Polycomb_High', 469.3333),
#  ('8_Enhancer_High', 470.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 470.3333),
#  ('8_Enhancer_High', 471.3333),
#  ('8_Enhancer_High', 471.6667),
#  ('1_Repressed_Polycomb_High', 471.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 472.3333),
#  ('1_Repressed_Polycomb_High', 474.6667),
#  ('8_Enhancer_High', 476.6667),
#  ('9_Active_Enhancer_High', 476.6667),
#  ('8_Enhancer_High', 477.0),
#  ('8_Enhancer_High', 477.3333),
#  ('8_Enhancer_High', 478.0),
#  ('1_Repressed_Polycomb_High', 478.3333),
#  ('8_Enhancer_High', 479.0),
#  ('8_Enhancer_High', 480.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 480.0),
#  ('8_Enhancer_High', 481.0),
#  ('1_Repressed_Polycomb_High', 481.3333),
#  ('1_Repressed_Polycomb_High', 482.0),
#  ('8_Enhancer_High', 483.0),
#  ('8_Enhancer_High', 485.3333),
#  ('1_Repressed_Polycomb_High', 486.0),
#  ('1_Repressed_Polycomb_High', 486.3333),
#  ('8_Enhancer_High', 486.6667),
#  ('9_Active_Enhancer_High', 487.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 487.3333),
#  ('1_Repressed_Polycomb_High', 487.3333),
#  ('1_Repressed_Polycomb_High', 487.6667),
#  ('9_Active_Enhancer_High', 488.3333),
#  ('8_Enhancer_High', 488.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 488.3333),
#  ('8_Enhancer_High', 490.0),
#  ('1_Repressed_Polycomb_High', 490.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 490.6667),
#  ('9_Active_Enhancer_High', 491.0),
#  ('8_Enhancer_High', 491.0),
#  ('9_Active_Enhancer_High', 491.0),
#  ('8_Enhancer_High', 492.0),
#  ('1_Repressed_Polycomb_High', 493.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 494.0),
#  ('9_Active_Enhancer_High', 494.3333),
#  ('1_Repressed_Polycomb_High', 495.3333),
#  ('9_Active_Enhancer_High', 495.6667),
#  ('8_Enhancer_High', 496.0),
#  ('9_Active_Enhancer_High', 496.0),
#  ('9_Active_Enhancer_High', 496.6667),
#  ('8_Enhancer_High', 496.6667),
#  ('8_Enhancer_High', 497.3333),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 497.6667),
#  ('8_Enhancer_High', 499.3333),
#  ('8_Enhancer_High', 499.6667),
#  ('8_Enhancer_High', 501.3333),
#  ('8_Enhancer_High', 501.6667),
#  ('1_Repressed_Polycomb_High', 502.3333),
#  ('8_Enhancer_High', 503.6667),
#  ('8_Enhancer_High', 504.3333),
#  ('1_Repressed_Polycomb_High', 506.0),
#  ('1_Repressed_Polycomb_High', 508.0),
#  ('9_Active_Enhancer_High', 508.0),
#  ('8_Enhancer_High', 509.3333),
#  ('3_Low_signal', 510.0),
#  ('1_Repressed_Polycomb_High', 510.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 511.0),
#  ('9_Active_Enhancer_High', 513.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 514.6667),
#  ('1_Repressed_Polycomb_High', 515.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 515.6667),
#  ('8_Enhancer_High', 516.3333),
#  ('9_Active_Enhancer_High', 516.6667),
#  ('8_Enhancer_High', 517.0),
#  ('8_Enhancer_High', 517.0),
#  ('1_Repressed_Polycomb_High', 517.6667),
#  ('9_Active_Enhancer_High', 518.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 518.3333),
#  ('9_Active_Enhancer_High', 518.6667),
#  ('9_Active_Enhancer_High', 519.6667),
#  ('1_Repressed_Polycomb_High', 520.0),
#  ('8_Enhancer_High', 520.3333),
#  ('1_Repressed_Polycomb_High', 520.3333),
#  ('1_Repressed_Polycomb_High', 521.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 521.0),
#  ('8_Enhancer_High', 521.6667),
#  ('11_Active_TSS_High_Signal_H3K4me3_H3K4me1', 522.0),
#  ('9_Active_Enhancer_High', 522.3333),
#  ('1_Repressed_Polycomb_High', 522.3333),
#  ('3_Low_signal', 523.3333),
#  ('9_Active_Enhancer_High', 523.3333),
#  ('8_Enhancer_High', 524.6667),
#  ('8_Enhancer_High', 525.0),
#  ('1_Repressed_Polycomb_High', 525.0),
#  ('8_Enhancer_High', 525.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 525.3333),
#  ('8_Enhancer_High', 526.3333),
#  ('1_Repressed_Polycomb_High', 527.6667),
#  ('1_Repressed_Polycomb_High', 528.3333),
#  ('8_Enhancer_High', 528.3333),
#  ('9_Active_Enhancer_High', 528.6667),
#  ('1_Repressed_Polycomb_High', 529.3333),
#  ('1_Repressed_Polycomb_High', 529.6667),
#  ('9_Active_Enhancer_High', 530.3333),
#  ('1_Repressed_Polycomb_High', 530.6667),
#  ('9_Active_Enhancer_High', 531.3333),
#  ('9_Active_Enhancer_High', 531.3333),
#  ('8_Enhancer_High', 531.6667),
#  ('1_Repressed_Polycomb_High', 532.0),
#  ('9_Active_Enhancer_High', 533.0),
#  ('9_Active_Enhancer_High', 533.3333),
#  ('1_Repressed_Polycomb_High', 533.6667),
#  ('8_Enhancer_High', 535.3333),
#  ('1_Repressed_Polycomb_High', 536.3333),
#  ('1_Repressed_Polycomb_High', 536.6667),
#  ('9_Active_Enhancer_High', 537.3333),
#  ('1_Repressed_Polycomb_High', 537.6667),
#  ('8_Enhancer_High', 538.0),
#  ('9_Active_Enhancer_High', 538.3333),
#  ('1_Repressed_Polycomb_High', 538.6667),
#  ('1_Repressed_Polycomb_High', 539.0),
#  ('1_Repressed_Polycomb_High', 540.3333),
#  ('1_Repressed_Polycomb_High', 541.0),
#  ('1_Repressed_Polycomb_High', 541.3333),
#  ('1_Repressed_Polycomb_High', 541.3333),
#  ('1_Repressed_Polycomb_High', 541.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 542.3333),
#  ('1_Repressed_Polycomb_High', 542.6667),
#  ('1_Repressed_Polycomb_High', 543.3333),
#  ('9_Active_Enhancer_High', 546.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 547.0),
#  ('9_Active_Enhancer_High', 547.0),
#  ('9_Active_Enhancer_High', 547.0),
#  ('9_Active_Enhancer_High', 547.0),
#  ('9_Active_Enhancer_High', 548.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 550.0),
#  ('9_Active_Enhancer_High', 551.0),
#  ('9_Active_Enhancer_High', 552.0),
#  ('1_Repressed_Polycomb_High', 553.3333),
#  ('1_Repressed_Polycomb_High', 554.6667),
#  ('9_Active_Enhancer_High', 555.3333),
#  ('1_Repressed_Polycomb_High', 556.3333),
#  ('8_Enhancer_High', 557.0),
#  ('1_Repressed_Polycomb_High', 557.6667),
#  ('1_Repressed_Polycomb_High', 557.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 559.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 559.6667),
#  ('1_Repressed_Polycomb_High', 560.3333),
#  ('1_Repressed_Polycomb_High', 560.6667),
#  ('1_Repressed_Polycomb_High', 561.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 561.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 561.6667),
#  ('1_Repressed_Polycomb_High', 562.3333),
#  ('1_Repressed_Polycomb_High', 562.3333),
#  ('1_Repressed_Polycomb_High', 564.3333),
#  ('9_Active_Enhancer_High', 564.6667),
#  ('1_Repressed_Polycomb_High', 565.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 566.6667),
#  ('1_Repressed_Polycomb_High', 566.6667),
#  ('1_Repressed_Polycomb_High', 568.0),
#  ('1_Repressed_Polycomb_High', 568.0),
#  ('9_Active_Enhancer_High', 568.0),
#  ('1_Repressed_Polycomb_High', 568.3333),
#  ('9_Active_Enhancer_High', 568.3333),
#  ('1_Repressed_Polycomb_High', 569.0),
#  ('1_Repressed_Polycomb_High', 569.3333),
#  ('1_Repressed_Polycomb_High', 570.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 570.6667),
#  ('3_Low_signal', 572.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 574.0),
#  ('3_Low_signal', 580.3333),
#  ('3_Low_signal', 589.6667),
#  ('3_Low_signal', 609.6667),
#  ('3_Low_signal', 621.6667),
#  ('3_Low_signal', 627.3333),
#  ('3_Low_signal', 642.6667),
#  ('3_Low_signal', 644.0),
#  ('3_Low_signal', 645.6667),
#  ('3_Low_signal', 650.0),
#  ('3_Low_signal', 650.3333),
#  ('3_Low_signal', 650.3333),
#  ('3_Low_signal', 652.3333),
#  ('3_Low_signal', 652.3333),
#  ('3_Low_signal', 659.0),
#  ('3_Low_signal', 659.0),
#  ('3_Low_signal', 667.0),
#  ('3_Low_signal', 670.0),
#  ('3_Low_signal', 671.3333),
#  ('3_Low_signal', 672.0),
#  ('3_Low_signal', 675.0),
#  ('3_Low_signal', 680.3333),
#  ('3_Low_signal', 681.0),
#  ('3_Low_signal', 683.6667),
#  ('3_Low_signal', 683.6667),
#  ('3_Low_signal', 684.6667),
#  ('3_Low_signal', 685.0),
#  ('3_Low_signal', 687.3333),
#  ('3_Low_signal', 691.6667),
#  ('3_Low_signal', 696.3333),
#  ('3_Low_signal', 699.0),
#  ('3_Low_signal', 700.3333),
#  ('3_Low_signal', 700.6667),
#  ('3_Low_signal', 701.6667),
#  ('3_Low_signal', 706.0),
#  ('3_Low_signal', 706.6667),
#  ('3_Low_signal', 707.3333),
#  ('3_Low_signal', 712.0),
#  ('3_Low_signal', 713.0),
#  ('3_Low_signal', 715.6667),
#  ('3_Low_signal', 719.3333),
#  ('3_Low_signal', 721.0),
#  ('3_Low_signal', 722.3333),
#  ('3_Low_signal', 723.6667),
#  ('3_Low_signal', 727.6667),
#  ('3_Low_signal', 730.6667),
#  ('3_Low_signal', 735.3333),
#  ('3_Low_signal', 737.0),
#  ('3_Low_signal', 738.0),
#  ('3_Low_signal', 738.6667),
#  ('3_Low_signal', 741.0),
#  ('3_Low_signal', 741.6667),
#  ('3_Low_signal', 744.0),
#  ('3_Low_signal', 744.6667),
#  ('3_Low_signal', 745.3333),
#  ('3_Low_signal', 747.6667),
#  ('3_Low_signal', 749.3333),
#  ('3_Low_signal', 750.0),
#  ('3_Low_signal', 751.6667),
#  ('3_Low_signal', 753.0),
#  ('3_Low_signal', 754.3333),
#  ('3_Low_signal', 758.0),
#  ('3_Low_signal', 758.6667),
#  ('3_Low_signal', 759.6667),
#  ('3_Low_signal', 764.6667),
#  ('3_Low_signal', 766.6667),
#  ('3_Low_signal', 768.0),
#  ('3_Low_signal', 768.0),
#  ('3_Low_signal', 768.3333),
#  ('3_Low_signal', 768.6667),
#  ('3_Low_signal', 769.6667),
#  ('3_Low_signal', 770.0),
#  ('3_Low_signal', 770.0),
#  ('3_Low_signal', 773.3333),
#  ('3_Low_signal', 773.6667),
#  ('3_Low_signal', 774.0),
#  ('3_Low_signal', 774.0),
#  ('3_Low_signal', 776.6667),
#  ('3_Low_signal', 777.0),
#  ('3_Low_signal', 779.0),
#  ('3_Low_signal', 779.6667),
#  ('3_Low_signal', 781.3333),
#  ('3_Low_signal', 781.6667),
#  ('3_Low_signal', 782.6667),
#  ('3_Low_signal', 783.3333),
#  ('3_Low_signal', 788.3333),
#  ('3_Low_signal', 794.0),
#  ('3_Low_signal', 796.0),
#  ('3_Low_signal', 796.6667),
#  ('3_Low_signal', 800.6667),
#  ('3_Low_signal', 800.6667),
#  ('3_Low_signal', 801.6667),
#  ('3_Low_signal', 804.0),
#  ('3_Low_signal', 804.0),
#  ('3_Low_signal', 804.0),
#  ('3_Low_signal', 804.3333),
#  ('3_Low_signal', 805.6667),
#  ('3_Low_signal', 806.0),
#  ('3_Low_signal', 806.3333),
#  ('3_Low_signal', 809.3333),
#  ('3_Low_signal', 811.6667),
#  ('3_Low_signal', 814.3333),
#  ('3_Low_signal', 815.3333),
#  ('3_Low_signal', 818.3333),
#  ('3_Low_signal', 823.3333),
#  ('3_Low_signal', 823.3333),
#  ('8_Enhancer_High', 823.3333),
#  ('3_Low_signal', 825.0),
#  ('8_Enhancer_High', 826.6667),
#  ('3_Low_signal', 828.3333),
#  ('3_Low_signal', 829.3333),
#  ('3_Low_signal', 829.6667),
#  ('3_Low_signal', 830.0),
#  ('8_Enhancer_High', 830.3333),
#  ('3_Low_signal', 835.0),
#  ('3_Low_signal', 840.6667),
#  ('3_Low_signal', 841.6667),
#  ('8_Enhancer_High', 842.0),
#  ('3_Low_signal', 842.6667),
#  ('3_Low_signal', 843.0),
#  ('8_Enhancer_High', 844.6667),
#  ('3_Low_signal', 845.3333),
#  ('9_Active_Enhancer_High', 847.0),
#  ('3_Low_signal', 848.0),
#  ('8_Enhancer_High', 849.0),
#  ('3_Low_signal', 850.0),
#  ('3_Low_signal', 850.3333),
#  ('9_Active_Enhancer_High', 850.3333),
#  ('8_Enhancer_High', 850.6667),
#  ('8_Enhancer_High', 851.6667),
#  ('3_Low_signal', 852.3333),
#  ('8_Enhancer_High', 852.6667),
#  ('3_Low_signal', 852.6667),
#  ('3_Low_signal', 853.3333),
#  ('3_Low_signal', 853.6667),
#  ('3_Low_signal', 855.6667),
#  ('3_Low_signal', 858.3333),
#  ('3_Low_signal', 861.3333),
#  ('8_Enhancer_High', 863.0),
#  ('8_Enhancer_High', 865.3333),
#  ('3_Low_signal', 865.6667),
#  ('9_Active_Enhancer_High', 866.0),
#  ('3_Low_signal', 868.6667),
#  ('8_Enhancer_High', 869.3333),
#  ('8_Enhancer_High', 869.6667),
#  ('3_Low_signal', 871.0),
#  ('3_Low_signal', 871.3333),
#  ('8_Enhancer_High', 873.3333),
#  ('8_Enhancer_High', 875.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 876.0),
#  ('8_Enhancer_High', 876.3333),
#  ('8_Enhancer_High', 878.3333),
#  ('8_Enhancer_High', 879.0),
#  ('8_Enhancer_High', 879.3333),
#  ('9_Active_Enhancer_High', 879.3333),
#  ('3_Low_signal', 880.0),
#  ('3_Low_signal', 881.0),
#  ('8_Enhancer_High', 881.3333),
#  ('9_Active_Enhancer_High', 881.6667),
#  ('9_Active_Enhancer_High', 882.6667),
#  ('9_Active_Enhancer_High', 883.6667),
#  ('9_Active_Enhancer_High', 885.0),
#  ('8_Enhancer_High', 886.0),
#  ('8_Enhancer_High', 887.0),
#  ('1_Repressed_Polycomb_High', 887.3333),
#  ('3_Low_signal', 887.6667),
#  ('3_Low_signal', 887.6667),
#  ('9_Active_Enhancer_High', 888.0),
#  ('8_Enhancer_High', 888.6667),
#  ('3_Low_signal', 889.3333),
#  ('1_Repressed_Polycomb_High', 889.3333),
#  ('1_Repressed_Polycomb_High', 892.0),
#  ('3_Low_signal', 892.0),
#  ('1_Repressed_Polycomb_High', 892.0),
#  ('1_Repressed_Polycomb_High', 894.0),
#  ('9_Active_Enhancer_High', 894.6667),
#  ('1_Repressed_Polycomb_High', 896.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 896.6667),
#  ('3_Low_signal', 897.0),
#  ('1_Repressed_Polycomb_High', 897.6667),
#  ('3_Low_signal', 898.0),
#  ('9_Active_Enhancer_High', 898.3333),
#  ('3_Low_signal', 899.0),
#  ('3_Low_signal', 899.6667),
#  ('3_Low_signal', 900.3333),
#  ('8_Enhancer_High', 900.6667),
#  ('9_Active_Enhancer_High', 901.0),
#  ('3_Low_signal', 901.0),
#  ('1_Repressed_Polycomb_High', 902.3333),
#  ('1_Repressed_Polycomb_High', 902.6667),
#  ('3_Low_signal', 903.3333),
#  ('9_Active_Enhancer_High', 904.0),
#  ('1_Repressed_Polycomb_High', 904.3333),
#  ('3_Low_signal', 905.0),
#  ('3_Low_signal', 905.0),
#  ('3_Low_signal', 905.3333),
#  ('3_Low_signal', 906.0),
#  ('9_Active_Enhancer_High', 906.6667),
#  ('1_Repressed_Polycomb_High', 907.3333),
#  ('3_Low_signal', 907.6667),
#  ('1_Repressed_Polycomb_High', 908.3333),
#  ('8_Enhancer_High', 908.3333),
#  ('3_Low_signal', 909.0),
#  ('8_Enhancer_High', 909.6667),
#  ('9_Active_Enhancer_High', 910.0),
#  ('8_Enhancer_High', 910.0),
#  ('1_Repressed_Polycomb_High', 911.0),
#  ('8_Enhancer_High', 911.0),
#  ('3_Low_signal', 911.6667),
#  ('1_Repressed_Polycomb_High', 912.3333),
#  ('8_Enhancer_High', 913.3333),
#  ('1_Repressed_Polycomb_High', 914.0),
#  ('9_Active_Enhancer_High', 914.3333),
#  ('3_Low_signal', 914.6667),
#  ('9_Active_Enhancer_High', 914.6667),
#  ('8_Enhancer_High', 915.3333),
#  ('3_Low_signal', 915.3333),
#  ('9_Active_Enhancer_High', 917.0),
#  ('3_Low_signal', 918.3333),
#  ('9_Active_Enhancer_High', 918.6667),
#  ('3_Low_signal', 920.3333),
#  ('8_Enhancer_High', 920.3333),
#  ('9_Active_Enhancer_High', 921.0),
#  ('8_Enhancer_High', 921.6667),
#  ('8_Enhancer_High', 922.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 922.3333),
#  ('1_Repressed_Polycomb_High', 923.0),
#  ('1_Repressed_Polycomb_High', 924.3333),
#  ('8_Enhancer_High', 924.6667),
#  ('1_Repressed_Polycomb_High', 925.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 925.3333),
#  ('3_Low_signal', 925.6667),
#  ('1_Repressed_Polycomb_High', 926.3333),
#  ('1_Repressed_Polycomb_High', 926.6667),
#  ('3_Low_signal', 928.3333),
#  ('3_Low_signal', 929.0),
#  ('3_Low_signal', 929.0),
#  ('9_Active_Enhancer_High', 929.0),
#  ('3_Low_signal', 929.3333),
#  ('3_Low_signal', 929.3333),
#  ('1_Repressed_Polycomb_High', 930.6667),
#  ('8_Enhancer_High', 931.3333),
#  ('3_Low_signal', 934.0),
#  ('1_Repressed_Polycomb_High', 934.6667),
#  ('1_Repressed_Polycomb_High', 935.6667),
#  ('1_Repressed_Polycomb_High', 938.0),
#  ('1_Repressed_Polycomb_High', 938.6667),
#  ('8_Enhancer_High', 939.0),
#  ('3_Low_signal', 939.3333),
#  ('1_Repressed_Polycomb_High', 944.0),
#  ('9_Active_Enhancer_High', 945.3333),
#  ('1_Repressed_Polycomb_High', 951.3333),
#  ('9_Active_Enhancer_High', 951.3333),
#  ('1_Repressed_Polycomb_High', 952.6667),
#  ('1_Repressed_Polycomb_High', 953.0),
#  ('1_Repressed_Polycomb_High', 954.6667),
#  ('1_Repressed_Polycomb_High', 955.6667),
#  ('9_Active_Enhancer_High', 957.6667),
#  ('3_Low_signal', 958.3333),
#  ('3_Low_signal', 959.0),
#  ('9_Active_Enhancer_High', 959.3333),
#  ('1_Repressed_Polycomb_High', 961.0),
#  ('8_Enhancer_High', 961.3333),
#  ('8_Enhancer_High', 963.3333),
#  ('1_Repressed_Polycomb_High', 966.0),
#  ('3_Low_signal', 966.0),
#  ('1_Repressed_Polycomb_High', 966.6667),
#  ('3_Low_signal', 969.0),
#  ('1_Repressed_Polycomb_High', 970.6667),
#  ('9_Active_Enhancer_High', 971.0),
#  ('1_Repressed_Polycomb_High', 971.3333),
#  ('3_Low_signal', 971.6667),
#  ('9_Active_Enhancer_High', 971.6667),
#  ('9_Active_Enhancer_High', 972.3333),
#  ('10_Distal_Active_Promoter_2Kb_High', 976.3333),
#  ('9_Active_Enhancer_High', 979.0),
#  ('8_Enhancer_High', 980.6667),
#  ('9_Active_Enhancer_High', 983.0),
#  ('8_Enhancer_High', 983.3333),
#  ('9_Active_Enhancer_High', 986.0),
#  ('1_Repressed_Polycomb_High', 986.0),
#  ('8_Enhancer_High', 986.3333),
#  ('1_Repressed_Polycomb_High', 987.3333),
#  ('1_Repressed_Polycomb_High', 987.3333),
#  ('3_Low_signal', 987.6667),
#  ('9_Active_Enhancer_High', 988.0),
#  ('8_Enhancer_High', 989.6667),
#  ('1_Repressed_Polycomb_High', 990.0),
#  ('3_Low_signal', 990.3333),
#  ('9_Active_Enhancer_High', 991.6667),
#  ('9_Active_Enhancer_High', 992.3333),
#  ('9_Active_Enhancer_High', 993.0),
#  ('1_Repressed_Polycomb_High', 993.6667),
#  ('1_Repressed_Polycomb_High', 994.3333),
#  ('3_Low_signal', 994.3333),
#  ('8_Enhancer_High', 995.0),
#  ('9_Active_Enhancer_High', 995.3333),
#  ('9_Active_Enhancer_High', 995.6667),
#  ('6_Transcription_Low', 996.6667),
#  ('8_Enhancer_High', 998.0),
#  ('8_Enhancer_High', 999.0),
#  ('8_Enhancer_High', 999.3333),
#  ('9_Active_Enhancer_High', 1001.0),
#  ('1_Repressed_Polycomb_High', 1001.6667),
#  ('10_Distal_Active_Promoter_2Kb_High', 1002.6667),
#  ('9_Active_Enhancer_High', 1002.6667),
#  ('9_Active_Enhancer_High', 1003.0),
#  ('1_Repressed_Polycomb_High', 1003.3333),
#  ('8_Enhancer_High', 1006.0),
#  ('1_Repressed_Polycomb_High', 1007.3333),
#  ('1_Repressed_Polycomb_High', 1007.3333),
#  ('9_Active_Enhancer_High', 1008.0),
#  ('1_Repressed_Polycomb_High', 1008.3333),
#  ('1_Repressed_Polycomb_High', 1009.6667),
#  ('1_Repressed_Polycomb_High', 1011.6667),
#  ('8_Enhancer_High', 1013.0),
#  ('8_Enhancer_High', 1016.0),
#  ('8_Enhancer_High', 1017.0),
#  ('1_Repressed_Polycomb_High', 1019.6667),
#  ('8_Enhancer_High', 1019.6667),
#  ('1_Repressed_Polycomb_High', 1020.3333),
#  ('1_Repressed_Polycomb_High', 1021.3333),
#  ('9_Active_Enhancer_High', 1022.0),
#  ('1_Repressed_Polycomb_High', 1024.0),
#  ('9_Active_Enhancer_High', 1024.3334),
#  ('1_Repressed_Polycomb_High', 1025.0),
#  ('6_Transcription_Low', 1028.6666),
#  ('1_Repressed_Polycomb_High', 1028.6666),
#  ('9_Active_Enhancer_High', 1029.6666),
#  ('9_Active_Enhancer_High', 1035.0),
#  ('1_Repressed_Polycomb_High', 1037.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 1042.3334),
#  ('9_Active_Enhancer_High', 1047.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 1050.6666),
#  ('2_Repressed_Polycomb_Low', 1051.6666),
#  ('9_Active_Enhancer_High', 1052.0),
#  ('9_Active_Enhancer_High', 1053.3334),
#  ('8_Enhancer_High', 1055.6666),
#  ('9_Active_Enhancer_High', 1056.0),
#  ('1_Repressed_Polycomb_High', 1057.0),
#  ('1_Repressed_Polycomb_High', 1057.3334),
#  ('8_Enhancer_High', 1060.6666),
#  ('9_Active_Enhancer_High', 1062.0),
#  ('10_Distal_Active_Promoter_2Kb_High', 1062.3334),
#  ('9_Active_Enhancer_High', 1064.6666),
#  ('1_Repressed_Polycomb_High', 1067.3334),
#  ('9_Active_Enhancer_High', 1067.6666),
#  ('8_Enhancer_High', 1073.6666),
#  ('9_Active_Enhancer_High', 1078.0),
#  ('1_Repressed_Polycomb_High', 1078.3334),
#  ('10_Distal_Active_Promoter_2Kb_High', 1079.6666),
#  ('2_Repressed_Polycomb_Low', 1082.0),
#  ('8_Enhancer_High', 1082.6666),
#  ('1_Repressed_Polycomb_High', 1084.0),
#  ('9_Active_Enhancer_High', 1086.3334),
#  ('8_Enhancer_High', 1088.6666),
#  ('9_Active_Enhancer_High', 1091.6666),
#  ('1_Repressed_Polycomb_High', 1092.0),
#  ('1_Repressed_Polycomb_High', 1092.3334),
#  ('1_Repressed_Polycomb_High', 1093.6666),
#  ('8_Enhancer_High', 1096.6666),
#  ('8_Enhancer_High', 1096.6666),
#  ('1_Repressed_Polycomb_High', 1101.3334),
#  ('1_Repressed_Polycomb_High', 1105.0),
#  ('1_Repressed_Polycomb_High', 1108.0),
#  ('2_Repressed_Polycomb_Low', 1109.6666),
#  ('9_Active_Enhancer_High', 1111.3334),
#  ('9_Active_Enhancer_High', 1118.0),
#  ('6_Transcription_Low', 1122.6666),
#  ('1_Repressed_Polycomb_High', 1127.6666),
#  ('10_Distal_Active_Promoter_2Kb_High', 1130.3334),
#  ('1_Repressed_Polycomb_High', 1130.3334),
#  ('8_Enhancer_High', 1130.6666),
#  ('9_Active_Enhancer_High', 1131.0),
#  ('1_Repressed_Polycomb_High', 1132.3334),
#  ('8_Enhancer_High', 1132.6666),
#  ('1_Repressed_Polycomb_High', 1133.0),
#  ('6_Transcription_Low', 1134.6666),
#  ('9_Active_Enhancer_High', 1138.6666),
# ...
#  ('2_Repressed_Polycomb_Low', 1546.0),
#  ('5_Transcription_High', 1546.6666),
#  ('5_Transcription_High', 1547.6666),
#  ('5_Transcription_High', 1548.3334),
#  ('4_Heterochromatin_High', 1548.3334),
#  ('2_Repressed_Polycomb_Low', 1549.0),
#  ('2_Repressed_Polycomb_Low', 1549.6666),
#  ('2_Repressed_Polycomb_Low', 1550.3334),
#  ('2_Repressed_Polycomb_Low', 1551.0),
#  ('7_Genic_Enhancer_High', 1551.0),
#  ('7_Genic_Enhancer_High', 1551.3334),
#  ('2_Repressed_Polycomb_Low', 1551.6666),
#  ('5_Transcription_High', 1551.6666),
#  ('4_Heterochromatin_High', 1553.0),
#  ('2_Repressed_Polycomb_Low', 1553.0),
#  ('4_Heterochromatin_High', 1553.3334),
#  ('2_Repressed_Polycomb_Low', 1553.6666),
#  ('5_Transcription_High', 1554.0),
#  ('5_Transcription_High', 1555.6666),
#  ('5_Transcription_High', 1556.0),
#  ('5_Transcription_High', 1559.3334),
#  ('5_Transcription_High', 1559.3334),
#  ('5_Transcription_High', 1560.3334),
#  ('5_Transcription_High', 1561.3334),
#  ('4_Heterochromatin_High', 1561.6666),
#  ('5_Transcription_High', 1563.6666),
#  ('5_Transcription_High', 1564.0),
#  ('7_Genic_Enhancer_High', 1564.3334),
#  ('7_Genic_Enhancer_High', 1564.3334),
#  ('2_Repressed_Polycomb_Low', 1564.6666),
#  ('7_Genic_Enhancer_High', 1565.3334),
#  ('5_Transcription_High', 1565.6666),
#  ('7_Genic_Enhancer_High', 1566.6666),
#  ('5_Transcription_High', 1567.0),
#  ('2_Repressed_Polycomb_Low', 1567.3334),
#  ('2_Repressed_Polycomb_Low', 1568.0),
#  ('7_Genic_Enhancer_High', 1568.3334),
#  ('7_Genic_Enhancer_High', 1568.6666),
#  ('7_Genic_Enhancer_High', 1570.0),
#  ('7_Genic_Enhancer_High', 1570.0),
#  ('5_Transcription_High', 1570.6666),
#  ('7_Genic_Enhancer_High', 1571.6666),
#  ('5_Transcription_High', 1573.6666),
#  ('2_Repressed_Polycomb_Low', 1574.0),
#  ('7_Genic_Enhancer_High', 1574.6666),
#  ('5_Transcription_High', 1575.0),
#  ('7_Genic_Enhancer_High', 1576.0),
#  ('5_Transcription_High', 1576.3334),
#  ('5_Transcription_High', 1578.0),
#  ('7_Genic_Enhancer_High', 1580.0),
#  ('5_Transcription_High', 1580.3334),
#  ('5_Transcription_High', 1580.3334),
#  ('5_Transcription_High', 1581.0),
#  ('5_Transcription_High', 1581.0),
#  ('5_Transcription_High', 1581.3334),
#  ('5_Transcription_High', 1581.6666),
#  ('7_Genic_Enhancer_High', 1581.6666),
#  ('7_Genic_Enhancer_High', 1582.0),
#  ('7_Genic_Enhancer_High', 1583.0),
#  ('5_Transcription_High', 1584.6666),
#  ('4_Heterochromatin_High', 1584.6666),
#  ('5_Transcription_High', 1585.3334),
#  ('2_Repressed_Polycomb_Low', 1587.3334),
#  ('7_Genic_Enhancer_High', 1587.6666),
#  ('7_Genic_Enhancer_High', 1588.6666),
#  ('4_Heterochromatin_High', 1588.6666),
#  ('7_Genic_Enhancer_High', 1588.6666),
#  ('5_Transcription_High', 1589.0),
#  ('2_Repressed_Polycomb_Low', 1589.0),
#  ('2_Repressed_Polycomb_Low', 1589.3334),
#  ('7_Genic_Enhancer_High', 1590.0),
#  ('4_Heterochromatin_High', 1591.6666),
#  ('2_Repressed_Polycomb_Low', 1591.6666),
#  ('2_Repressed_Polycomb_Low', 1592.0),
#  ('7_Genic_Enhancer_High', 1593.0),
#  ('7_Genic_Enhancer_High', 1593.6666),
#  ('4_Heterochromatin_High', 1594.0),
#  ('5_Transcription_High', 1595.0),
#  ('7_Genic_Enhancer_High', 1595.6666),
#  ('7_Genic_Enhancer_High', 1595.6666),
#  ('4_Heterochromatin_High', 1596.3334),
#  ('5_Transcription_High', 1599.0),
#  ('5_Transcription_High', 1599.3334),
#  ('5_Transcription_High', 1600.0),
#  ('7_Genic_Enhancer_High', 1600.3334),
#  ('5_Transcription_High', 1600.3334),
#  ('7_Genic_Enhancer_High', 1600.6666),
#  ('5_Transcription_High', 1601.3334),
#  ('5_Transcription_High', 1601.3334),
#  ('5_Transcription_High', 1601.6666),
#  ('7_Genic_Enhancer_High', 1601.6666),
#  ('7_Genic_Enhancer_High', 1604.0),
#  ('7_Genic_Enhancer_High', 1605.0),
#  ('7_Genic_Enhancer_High', 1605.6666),
#  ('5_Transcription_High', 1606.3334),
#  ('2_Repressed_Polycomb_Low', 1607.3334),
#  ('7_Genic_Enhancer_High', 1607.6666),
#  ('7_Genic_Enhancer_High', 1608.6666),
#  ('4_Heterochromatin_High', 1609.6666),
#  ('7_Genic_Enhancer_High', 1610.3334),
#  ('7_Genic_Enhancer_High', 1612.0),
#  ('7_Genic_Enhancer_High', 1613.0),
#  ('4_Heterochromatin_High', 1613.3334),
#  ('5_Transcription_High', 1613.6666),
#  ('2_Repressed_Polycomb_Low', 1614.3334),
#  ('7_Genic_Enhancer_High', 1615.0),
#  ('7_Genic_Enhancer_High', 1615.3334),
#  ('7_Genic_Enhancer_High', 1615.6666),
#  ('7_Genic_Enhancer_High', 1616.0),
#  ('5_Transcription_High', 1616.0),
#  ('7_Genic_Enhancer_High', 1616.0),
#  ('7_Genic_Enhancer_High', 1617.0),
#  ('5_Transcription_High', 1617.0),
#  ('7_Genic_Enhancer_High', 1617.3334),
#  ('5_Transcription_High', 1617.6666),
#  ('4_Heterochromatin_High', 1618.0),
#  ('7_Genic_Enhancer_High', 1618.0),
#  ('7_Genic_Enhancer_High', 1618.0),
#  ('5_Transcription_High', 1619.6666),
#  ('7_Genic_Enhancer_High', 1620.6666),
#  ('4_Heterochromatin_High', 1621.0),
#  ('7_Genic_Enhancer_High', 1621.0),
#  ('4_Heterochromatin_High', 1621.3334),
#  ('5_Transcription_High', 1621.3334),
#  ('7_Genic_Enhancer_High', 1621.6666),
#  ('5_Transcription_High', 1622.0),
#  ('7_Genic_Enhancer_High', 1622.3334),
#  ('7_Genic_Enhancer_High', 1622.6666),
#  ('7_Genic_Enhancer_High', 1623.3334),
#  ('5_Transcription_High', 1624.3334),
#  ('7_Genic_Enhancer_High', 1624.6666),
#  ('7_Genic_Enhancer_High', 1625.3334),
#  ('4_Heterochromatin_High', 1625.3334),
#  ('7_Genic_Enhancer_High', 1627.0),
#  ('7_Genic_Enhancer_High', 1627.0),
#  ('5_Transcription_High', 1627.0),
#  ('7_Genic_Enhancer_High', 1627.0),
#  ('7_Genic_Enhancer_High', 1627.3334),
#  ('4_Heterochromatin_High', 1628.3334),
#  ('7_Genic_Enhancer_High', 1629.3334),
#  ('5_Transcription_High', 1629.6666),
#  ('4_Heterochromatin_High', 1629.6666),
#  ('4_Heterochromatin_High', 1631.0),
#  ('4_Heterochromatin_High', 1632.6666),
#  ('5_Transcription_High', 1632.6666),
#  ('5_Transcription_High', 1634.6666),
#  ('5_Transcription_High', 1637.6666),
#  ('7_Genic_Enhancer_High', 1637.6666),
#  ('4_Heterochromatin_High', 1638.0),
#  ('4_Heterochromatin_High', 1638.0),
#  ('7_Genic_Enhancer_High', 1638.3334),
#  ('4_Heterochromatin_High', 1638.6666),
#  ('5_Transcription_High', 1641.0),
#  ('7_Genic_Enhancer_High', 1641.0),
#  ('4_Heterochromatin_High', 1642.3334),
#  ('7_Genic_Enhancer_High', 1643.3334),
#  ('5_Transcription_High', 1644.3334),
#  ('7_Genic_Enhancer_High', 1644.6666),
#  ('7_Genic_Enhancer_High', 1645.0),
#  ('7_Genic_Enhancer_High', 1645.6666),
#  ('7_Genic_Enhancer_High', 1646.3334),
#  ('5_Transcription_High', 1646.3334),
#  ('5_Transcription_High', 1646.6666),
#  ('4_Heterochromatin_High', 1647.0),
#  ('4_Heterochromatin_High', 1647.0),
#  ('5_Transcription_High', 1647.3334),
#  ('7_Genic_Enhancer_High', 1648.6666),
#  ('4_Heterochromatin_High', 1648.6666),
#  ('7_Genic_Enhancer_High', 1648.6666),
#  ('7_Genic_Enhancer_High', 1648.6666),
#  ('5_Transcription_High', 1649.0),
#  ('7_Genic_Enhancer_High', 1649.3334),
#  ('7_Genic_Enhancer_High', 1651.6666),
#  ('4_Heterochromatin_High', 1652.0),
#  ('5_Transcription_High', 1652.0),
#  ('7_Genic_Enhancer_High', 1653.3334),
#  ('4_Heterochromatin_High', 1654.6666),
#  ('7_Genic_Enhancer_High', 1654.6666),
#  ('7_Genic_Enhancer_High', 1656.0),
#  ('4_Heterochromatin_High', 1656.0),
#  ('2_Repressed_Polycomb_Low', 1656.6666),
#  ('7_Genic_Enhancer_High', 1657.0),
#  ('7_Genic_Enhancer_High', 1658.0),
#  ('7_Genic_Enhancer_High', 1659.3334),
#  ('5_Transcription_High', 1659.3334),
#  ('2_Repressed_Polycomb_Low', 1660.0),
#  ('7_Genic_Enhancer_High', 1660.3334),
#  ('7_Genic_Enhancer_High', 1660.6666),
#  ('5_Transcription_High', 1661.3334),
#  ('4_Heterochromatin_High', 1661.3334),
#  ('7_Genic_Enhancer_High', 1663.0),
#  ('7_Genic_Enhancer_High', 1663.3334),
#  ('7_Genic_Enhancer_High', 1663.6666),
#  ('4_Heterochromatin_High', 1664.6666),
#  ('5_Transcription_High', 1665.6666),
#  ('5_Transcription_High', 1666.0),
#  ('7_Genic_Enhancer_High', 1667.0),
#  ('7_Genic_Enhancer_High', 1667.3334),
#  ('2_Repressed_Polycomb_Low', 1668.6666),
#  ('7_Genic_Enhancer_High', 1669.0),
#  ('7_Genic_Enhancer_High', 1669.6666),
#  ('5_Transcription_High', 1670.3334),
#  ('7_Genic_Enhancer_High', 1670.6666),
#  ('5_Transcription_High', 1671.0),
#  ('4_Heterochromatin_High', 1671.0),
#  ('7_Genic_Enhancer_High', 1671.6666),
#  ('7_Genic_Enhancer_High', 1673.0),
#  ('7_Genic_Enhancer_High', 1673.6666),
#  ('7_Genic_Enhancer_High', 1673.6666),
#  ('5_Transcription_High', 1675.3334),
#  ('7_Genic_Enhancer_High', 1676.0),
#  ('7_Genic_Enhancer_High', 1676.0),
#  ('5_Transcription_High', 1676.3334),
#  ('7_Genic_Enhancer_High', 1676.3334),
#  ('5_Transcription_High', 1676.6666),
#  ('4_Heterochromatin_High', 1676.6666),
#  ('7_Genic_Enhancer_High', 1677.0),
#  ('7_Genic_Enhancer_High', 1678.0),
#  ('5_Transcription_High', 1679.0),
#  ('4_Heterochromatin_High', 1679.3334),
#  ('7_Genic_Enhancer_High', 1679.6666),
#  ('7_Genic_Enhancer_High', 1680.0),
#  ('7_Genic_Enhancer_High', 1680.6666),
#  ('4_Heterochromatin_High', 1681.0),
#  ('7_Genic_Enhancer_High', 1681.3334),
#  ('4_Heterochromatin_High', 1681.3334),
#  ('5_Transcription_High', 1681.6666),
#  ('7_Genic_Enhancer_High', 1682.0),
#  ('5_Transcription_High', 1682.0),
#  ('5_Transcription_High', 1683.3334),
#  ('4_Heterochromatin_High', 1685.0),
#  ('7_Genic_Enhancer_High', 1685.0),
#  ('4_Heterochromatin_High', 1685.6666),
#  ('7_Genic_Enhancer_High', 1686.6666),
#  ('7_Genic_Enhancer_High', 1687.3334),
#  ('7_Genic_Enhancer_High', 1687.6666),
#  ('4_Heterochromatin_High', 1688.0),
#  ('4_Heterochromatin_High', 1688.3334),
#  ('7_Genic_Enhancer_High', 1690.0),
#  ('7_Genic_Enhancer_High', 1693.0),
#  ('4_Heterochromatin_High', 1693.0),
#  ('4_Heterochromatin_High', 1694.0),
#  ('5_Transcription_High', 1694.0),
#  ('7_Genic_Enhancer_High', 1694.0),
#  ('7_Genic_Enhancer_High', 1694.3334),
#  ('7_Genic_Enhancer_High', 1694.6666),
#  ('4_Heterochromatin_High', 1698.6666),
#  ('4_Heterochromatin_High', 1699.0),
#  ('7_Genic_Enhancer_High', 1699.3334),
#  ('7_Genic_Enhancer_High', 1699.3334),
#  ('5_Transcription_High', 1699.6666),
#  ('7_Genic_Enhancer_High', 1703.0),
#  ('4_Heterochromatin_High', 1705.0),
#  ('4_Heterochromatin_High', 1705.0),
#  ('7_Genic_Enhancer_High', 1705.6666),
#  ('5_Transcription_High', 1706.3334),
#  ('7_Genic_Enhancer_High', 1710.0),
#  ('4_Heterochromatin_High', 1711.0),
#  ('4_Heterochromatin_High', 1711.6666),
#  ('4_Heterochromatin_High', 1712.6666),
#  ('7_Genic_Enhancer_High', 1716.0),
#  ('2_Repressed_Polycomb_Low', 1717.0),
#  ('4_Heterochromatin_High', 1717.3334),
#  ('7_Genic_Enhancer_High', 1720.0),
#  ('7_Genic_Enhancer_High', 1720.6666),
#  ('5_Transcription_High', 1721.3334),
#  ('7_Genic_Enhancer_High', 1727.3334),
#  ('7_Genic_Enhancer_High', 1728.6666),
#  ('4_Heterochromatin_High', 1729.0),
#  ('5_Transcription_High', 1729.3334),
#  ('4_Heterochromatin_High', 1729.6666),
#  ('4_Heterochromatin_High', 1730.6666),
#  ('4_Heterochromatin_High', 1731.3334),
#  ('4_Heterochromatin_High', 1732.3334),
#  ('4_Heterochromatin_High', 1733.0),
#  ('4_Heterochromatin_High', 1733.3334),
#  ('4_Heterochromatin_High', 1734.6666),
#  ('7_Genic_Enhancer_High', 1735.0),
#  ('7_Genic_Enhancer_High', 1735.3334),
#  ('7_Genic_Enhancer_High', 1735.6666),
#  ('4_Heterochromatin_High', 1736.6666),
#  ('4_Heterochromatin_High', 1737.0),
#  ('5_Transcription_High', 1737.6666),
#  ('7_Genic_Enhancer_High', 1738.6666),
#  ('4_Heterochromatin_High', 1738.6666),
#  ('7_Genic_Enhancer_High', 1739.3334),
#  ('4_Heterochromatin_High', 1740.3334),
#  ('4_Heterochromatin_High', 1741.3334),
#  ('7_Genic_Enhancer_High', 1741.6666),
#  ('4_Heterochromatin_High', 1741.6666),
#  ('4_Heterochromatin_High', 1742.6666),
#  ('7_Genic_Enhancer_High', 1743.6666),
#  ('7_Genic_Enhancer_High', 1744.0),
#  ('7_Genic_Enhancer_High', 1744.3334),
#  ('4_Heterochromatin_High', 1745.0),
#  ('4_Heterochromatin_High', 1745.3334),
#  ('4_Heterochromatin_High', 1746.0),
#  ('4_Heterochromatin_High', 1747.6666),
#  ('4_Heterochromatin_High', 1749.6666),
#  ('5_Transcription_High', 1751.0),
#  ('7_Genic_Enhancer_High', 1751.0),
#  ('4_Heterochromatin_High', 1751.6666),
#  ('4_Heterochromatin_High', 1753.0),
#  ('4_Heterochromatin_High', 1754.3334),
#  ('4_Heterochromatin_High', 1756.0),
#  ('7_Genic_Enhancer_High', 1756.6666),
#  ('7_Genic_Enhancer_High', 1757.0),
#  ('4_Heterochromatin_High', 1758.3334),
#  ('7_Genic_Enhancer_High', 1759.0),
#  ('4_Heterochromatin_High', 1759.3334),
#  ('4_Heterochromatin_High', 1760.6666),
#  ('4_Heterochromatin_High', 1763.0),
#  ('4_Heterochromatin_High', 1764.0),
#  ('4_Heterochromatin_High', 1764.0),
#  ('7_Genic_Enhancer_High', 1764.3334),
#  ('4_Heterochromatin_High', 1765.3334),
#  ('4_Heterochromatin_High', 1765.3334),
#  ('4_Heterochromatin_High', 1767.0),
#  ('4_Heterochromatin_High', 1768.0),
#  ('5_Transcription_High', 1770.3334),
#  ('4_Heterochromatin_High', 1770.6666),
#  ('4_Heterochromatin_High', 1771.6666),
#  ('4_Heterochromatin_High', 1774.3334),
#  ('4_Heterochromatin_High', 1775.0),
#  ('4_Heterochromatin_High', 1777.0),
#  ('4_Heterochromatin_High', 1777.3334),
#  ('5_Transcription_High', 1777.6666),
#  ('4_Heterochromatin_High', 1778.0),
#  ('4_Heterochromatin_High', 1780.6666),
#  ('4_Heterochromatin_High', 1782.0),
#  ('5_Transcription_High', 1782.3334),
#  ('4_Heterochromatin_High', 1782.3334),
#  ('4_Heterochromatin_High', 1783.6666),
#  ('4_Heterochromatin_High', 1783.6666),
#  ('5_Transcription_High', 1785.0),
#  ('7_Genic_Enhancer_High', 1785.3334),
#  ('4_Heterochromatin_High', 1786.3334),
#  ('4_Heterochromatin_High', 1786.3334),
#  ('4_Heterochromatin_High', 1786.6666),
#  ('4_Heterochromatin_High', 1787.0),
#  ('7_Genic_Enhancer_High', 1788.3334),
#  ('5_Transcription_High', 1788.6666),
#  ('4_Heterochromatin_High', 1790.0),
#  ('4_Heterochromatin_High', 1790.0),
#  ('4_Heterochromatin_High', 1791.6666),
#  ('4_Heterochromatin_High', 1791.6666),
#  ('4_Heterochromatin_High', 1792.3334),
#  ('4_Heterochromatin_High', 1793.6666),
#  ('4_Heterochromatin_High', 1794.0),
#  ('5_Transcription_High', 1795.0),
#  ('4_Heterochromatin_High', 1800.3334),
#  ('4_Heterochromatin_High', 1801.0),
#  ('7_Genic_Enhancer_High', 1803.0),
#  ('4_Heterochromatin_High', 1804.3334),
#  ('4_Heterochromatin_High', 1805.6666),
#  ('7_Genic_Enhancer_High', 1805.6666),
#  ('4_Heterochromatin_High', 1809.6666),
#  ('4_Heterochromatin_High', 1810.0),
#  ('4_Heterochromatin_High', 1812.3334),
#  ('4_Heterochromatin_High', 1815.6666),
#  ('4_Heterochromatin_High', 1819.3334),
#  ('2_Repressed_Polycomb_Low', 1821.6666),
#  ('4_Heterochromatin_High', 1822.0),
#  ('4_Heterochromatin_High', 1823.6666),
#  ('4_Heterochromatin_High', 1823.6666),
#  ('4_Heterochromatin_High', 1824.0),
#  ('4_Heterochromatin_High', 1825.3334),
#  ('4_Heterochromatin_High', 1825.6666),
#  ('4_Heterochromatin_High', 1827.6666),
#  ('4_Heterochromatin_High', 1828.6666),
#  ('5_Transcription_High', 1833.0),
#  ('7_Genic_Enhancer_High', 1833.3334),
#  ('4_Heterochromatin_High', 1834.3334),
#  ('4_Heterochromatin_High', 1834.3334),
#  ('4_Heterochromatin_High', 1834.3334),
#  ('4_Heterochromatin_High', 1836.0),
#  ('4_Heterochromatin_High', 1837.3334),
#  ('4_Heterochromatin_High', 1837.3334),
#  ('4_Heterochromatin_High', 1838.3334),
#  ('4_Heterochromatin_High', 1838.3334),
#  ('4_Heterochromatin_High', 1840.3334),
#  ('4_Heterochromatin_High', 1843.0),
#  ('4_Heterochromatin_High', 1844.6666),
#  ('4_Heterochromatin_High', 1848.0),
#  ('4_Heterochromatin_High', 1851.0),
#  ('4_Heterochromatin_High', 1856.6666),
#  ('4_Heterochromatin_High', 1858.6666),
#  ('4_Heterochromatin_High', 1861.3334),
#  ('4_Heterochromatin_High', 1862.0),
#  ('4_Heterochromatin_High', 1862.3334),
#  ('4_Heterochromatin_High', 1864.6666),
#  ('4_Heterochromatin_High', 1873.0),
#  ('4_Heterochromatin_High', 1874.3334),
#  ('4_Heterochromatin_High', 1876.0),
#  ('4_Heterochromatin_High', 1877.0),
#  ('4_Heterochromatin_High', 1879.6666),
#  ('4_Heterochromatin_High', 1881.0),
#  ('4_Heterochromatin_High', 1886.3334),
#  ('4_Heterochromatin_High', 1886.3334),
#  ('4_Heterochromatin_High', 1887.6666),
#  ('4_Heterochromatin_High', 1890.0),
#  ('4_Heterochromatin_High', 1891.6666),
#  ('4_Heterochromatin_High', 1895.3334),
#  ('4_Heterochromatin_High', 1898.3334),
#  ('4_Heterochromatin_High', 1904.0),
#  ('4_Heterochromatin_High', 1905.6666),
#  ('4_Heterochromatin_High', 1912.0),
#  ('4_Heterochromatin_High', 1916.3334),
#  ('4_Heterochromatin_High', 1916.6666),
#  ('4_Heterochromatin_High', 1929.0),
#  ('4_Heterochromatin_High', 1932.3334),
#  ('5_Transcription_High', 1946.3334),
#  ('7_Genic_Enhancer_High', 1953.3334),
#  ('5_Transcription_High', 1972.0),
#  ('4_Heterochromatin_High', 1972.6666),
#  ('4_Heterochromatin_High', 1973.0),
#  ('1_Repressed_Polycomb_High', 2076.0)]
