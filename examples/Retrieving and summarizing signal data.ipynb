# %%
import xmlrpclib

# %%
url = "http://deepblue.mpi-inf.mpg.de/xmlrpc"
deepblue = xmlrpclib.Server(url, allow_none=True)

# %%
USER_KEY = "anonymous_key"

# %%
print deepblue.echo(USER_KEY)
# Out:
# ['okay', 'DeepBlue (1.17.7) says hi to anonymous']

# %%
ds = grid_experiments = [ "MS027801.mRNASeq.signal_reverse.bedgraph",
		      "MS023101.mRNASeq.signal_forward.bedgraph",
		      "MS028601.mRNASeq.signal_forward.bedgraph",
		      "MS027801.mRNASeq.signal_forward.bedgraph",
		      "MS023001.mRNASeq.signal_forward.bedgraph",
		      "MS027501.mRNASeq.signal_reverse.bedgraph",
		      "MS027501.mRNASeq.signal_forward.bedgraph",
		      "MS029801.mRNASeq.signal_forward.bedgraph",
		      "MS027101.mRNASeq.signal_reverse.bedgraph",
		      "MS027101.mRNASeq.signal_forward.bedgraph",
		      "MS023201.mRNASeq.signal_forward.bedgraph",
		      "MS023501.mRNASeq.signal_forward.bedgraph",
		      "MS028901.mRNASeq.signal_forward.bedgraph",
		      "MS028901.mRNASeq.signal_reverse.bedgraph",
		      "MS028401.mRNASeq.signal_forward.bedgraph",
		      "MS028401.mRNASeq.signal_reverse.bedgraph",
		      "MS028201.mRNASeq.signal_reverse.bedgraph",
		      "MS028201.mRNASeq.signal_forward.bedgraph",
		      "MS023601.mRNASeq.signal_reverse.bedgraph",
		      "MS023601.mRNASeq.signal_forward.bedgraph",
		      "MS023301.mRNASeq.signal_forward.bedgraph",
		      "MS028301.mRNASeq.signal_reverse.bedgraph",
		      "MS023801.mRNASeq.signal_forward.bedgraph",
		      "MS029701.mRNASeq.signal_forward.bedgraph",
		      "MS029701.mRNASeq.signal_reverse.bedgraph",
		      "MS027601.mRNASeq.signal_forward.bedgraph",
		      "MS024101.mRNASeq.signal_reverse.bedgraph",
		      "MS024101.mRNASeq.signal_forward.bedgraph",
		      "MS029401.mRNASeq.signal_forward.bedgraph",
		      "MS029401.mRNASeq.signal_reverse.bedgraph",
		      "MS028701.mRNASeq.signal_reverse.bedgraph",
		      "MS028701.mRNASeq.signal_forward.bedgraph",
		      "MS029201.mRNASeq.signal_forward.bedgraph",
		      "MS023701.mRNASeq.signal_forward.bedgraph",
		      "MS023701.mRNASeq.signal_reverse.bedgraph",
		      "MS023201.mRNASeq.signal_reverse.bedgraph",
		      "MS028101.mRNASeq.signal_reverse.bedgraph",
		      "MS028601.mRNASeq.signal_reverse.bedgraph",
		      "MS028101.mRNASeq.signal_forward.bedgraph",
		      "MS023101.mRNASeq.signal_reverse.bedgraph",
		      "MS023001.mRNASeq.signal_reverse.bedgraph",
		      "MS029901.mRNASeq.signal_reverse.bedgraph",
		      "MS029901.mRNASeq.signal_forward.bedgraph",
		      "MS028301.mRNASeq.signal_forward.bedgraph",
		      "MS023301.mRNASeq.signal_reverse.bedgraph",
		      "MS024001.mRNASeq.signal_forward.bedgraph",
		      "MS024001.mRNASeq.signal_reverse.bedgraph",
		      "MS027301.mRNASeq.signal_reverse.bedgraph",
		      "MS027301.mRNASeq.signal_forward.bedgraph",
		      "MS027401.mRNASeq.signal_forward.bedgraph",
		      "MS027401.mRNASeq.signal_reverse.bedgraph",
		      "MS029201.mRNASeq.signal_reverse.bedgraph",
		      "MS023501.mRNASeq.signal_reverse.bedgraph",
		      "MS023801.mRNASeq.signal_reverse.bedgraph",
		      "MS028501.mRNASeq.signal_reverse.bedgraph",
		      "MS029801.mRNASeq.signal_reverse.bedgraph",
		      "MS028501.mRNASeq.signal_forward.bedgraph",
		      "MS029601.mRNASeq.signal_forward.bedgraph",
		      "MS029601.mRNASeq.signal_reverse.bedgraph",
		      "MS029301.mRNASeq.signal_forward.bedgraph",
		      "MS028801.mRNASeq.signal_reverse.bedgraph",
		      "MS029501.mRNASeq.signal_reverse.bedgraph",
		      "MS029501.mRNASeq.signal_forward.bedgraph",
		      "MS029301.mRNASeq.signal_reverse.bedgraph",
		      "MS027601.mRNASeq.signal_reverse.bedgraph",
		      "MS027201.mRNASeq.signal_reverse.bedgraph",
		      "MS027201.mRNASeq.signal_forward.bedgraph",
		      "MS027901.mRNASeq.signal_forward.bedgraph",
		      "MS027901.mRNASeq.signal_reverse.bedgraph",
		      "MS028801.mRNASeq.signal_forward.bedgraph",
		      "MS023901.mRNASeq.signal_reverse.bedgraph",
		      "MS023901.mRNASeq.signal_forward.bedgraph",
		      "MS027701.mRNASeq.signal_reverse.bedgraph",
		      "MS023401.mRNASeq.signal_reverse.bedgraph",
		      "MS029001.mRNASeq.signal_reverse.bedgraph",
		      "MS027701.mRNASeq.signal_forward.bedgraph",
		      "MS029001.mRNASeq.signal_forward.bedgraph",
		      "MS023401.mRNASeq.signal_forward.bedgraph",
		      "MS028001.mRNASeq.signal_forward.bedgraph",
		      "MS028001.mRNASeq.signal_reverse.bedgraph",
		      "MS029101.mRNASeq.signal_reverse.bedgraph",
		      "MS029101.mRNASeq.signal_forward.bedgraph" ]

# %%
(s, q) = deepblue.select_experiments(ds, "chr1", 934567,2650001, USER_KEY)
print q
# Out:
# q995545

# %%
s, r = deepblue.count_regions(q, USER_KEY)

# %%
import time
def download_data(request_id):
 (status, info) = deepblue.info(request_id, USER_KEY)
 print info
 request_status = info[0]["state"]
 while request_status != "done" and request_status != "failed":
   print request_status 
   time.sleep(1)
   (status, info) = deepblue.info(request_id, USER_KEY)
   request_status = info[0]["state"]
 (status, regions) = deepblue.get_request_data(request_id, USER_KEY)
 return regions

# %%
v = download_data(r)
v
# Out:
# [{'user_id': 'u23', 'finish_time': '2017-Dec-15 21:37:13.412000', 'state': 'done', 'create_time': '2017-Dec-15 21:37:04.286000', 'command': 'count_regions', 'query_id': 'q995545', 'message': '', '_id': 'r826088', 'type': 'request'}]
# {'count': 6498396}

# %%
deepblue.info(r, USER_KEY)
# Out:
# ['okay',
#  [{'_id': 'r826088',
#    'command': 'count_regions',
#    'create_time': '2017-Dec-15 21:37:04.286000',
#    'finish_time': '2017-Dec-15 21:37:13.412000',
#    'message': '',
#    'query_id': 'q995545',
#    'state': 'done',
#    'type': 'request',
#    'user_id': 'u23'}]]

# %%
s, bins = deepblue.tiling_regions (100, "hg19", "chr1", USER_KEY)
print bins
s, interest = deepblue.input_regions("hg19", "chr1\t934567\t2650001", USER_KEY)
print interest
s, overlap_bins = deepblue.intersection ( bins, interest, USER_KEY)
print overlap_bins
# Out:
# q995551
# q995552
# q995553

# %%
s, aggr = deepblue.aggregate (q, overlap_bins, "VALUE", USER_KEY)

# %%
s, r = deepblue.get_regions(aggr, "CHROMOSOME,START,END,@AGG.MEAN,@AGG.COUNT", USER_KEY)

# %%
v = download_data(r)
# Out:
# [{'user_id': 'u23', 'format': 'CHROMOSOME,START,END,@AGG.MEAN,@AGG.COUNT', 'state': 'running', 'create_time': '2017-Dec-15 21:38:24.534000', 'command': 'get_regions', 'query_id': 'q995554', 'message': '', '_id': 'r826090', 'type': 'request'}]
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running

# %%
print v
# Out:
# chr1	934550	934575	0.2050	12
# chr1	934575	934600	0.3106	23
# chr1	934600	934625	0.3999	41
# chr1	934625	934650	0.3901	50
# chr1	934650	934675	0.4165	45
# chr1	934675	934700	0.4291	78
# chr1	934700	934725	0.6627	82
# chr1	934725	934750	0.5896	83
# chr1	934750	934775	0.6930	80
# chr1	934775	934800	0.7081	100
# chr1	934800	934825	0.4928	55
# chr1	934825	934850	0.1625	5
# chr1	934850	934875	0.1200	3
# chr1	934875	934900	0.1259	9
# chr1	934900	934925	0.7883	86
# chr1	934925	934950	0.6833	111
# chr1	934950	934975	0.7876	108
# chr1	934975	935000	0.8497	162
# chr1	935000	935025	0.4283	80
# chr1	935025	935050	0.5025	83
# chr1	935050	935075	0.5199	106
# chr1	935075	935100	0.7603	137
# chr1	935100	935125	0.4941	91
# chr1	935125	935150	0.4440	97
# chr1	935150	935175	0.5314	84
# chr1	935175	935200	0.2654	54
# chr1	935200	935225	0.1613	19
# chr1	935225	935250	0.2588	43
# chr1	935250	935275	0.3118	54
# chr1	935275	935300	0.3286	43
# chr1	935300	935325	0.3236	48
# chr1	935325	935350	0.2404	40
# ...
